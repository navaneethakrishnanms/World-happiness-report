# %%
import numpy as np
import pandas as pd
df=pd.read_csv('World-happiness-report-2024.csv')
df.head(10)
# Out:
#   Country name            Regional indicator  Ladder score  upperwhisker  \
# 0      Finland                Western Europe         7.741         7.815
# 1      Denmark                Western Europe         7.583         7.665
# 2      Iceland                Western Europe         7.525         7.618
# 3       Sweden                Western Europe         7.344         7.422
# 4       Israel  Middle East and North Africa         7.341         7.405
# 5  Netherlands                Western Europe         7.319         7.383
# 6       Norway                Western Europe         7.302         7.389
# 7   Luxembourg                Western Europe         7.122         7.213
# 8  Switzerland                Western Europe         7.060         7.147
# 9    Australia         North America and ANZ         7.057         7.141
#
#    lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# 0         7.667               1.844           1.572                    0.695
# ...

# %%
a=df.shape
print(a)
b=df.columns
print(b)
c=df.dtypes
print(c)
k=df.isnull().sum()
print(k)
x=df.duplicated().sum()
print("duplicated :",x)
# Out:
# (143, 12)
# Index(['Country name', 'Regional indicator', 'Ladder score', 'upperwhisker',
#        'lowerwhisker', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')
# Country name                     object
# Regional indicator               object
# Ladder score                    float64
# upperwhisker                    float64
# lowerwhisker                    float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object
# Country name                    0
# Regional indicator              0
# Ladder score                    0
# upperwhisker                    0
# ...

# %%
cols_to_fill = ['Log GDP per capita', 'Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption','Dystopia + residual']
for col in cols_to_fill:
    df[col].fillna(df[col].mean(), inplace=True)
# Out:
# C:\Users\nithi\AppData\Local\Temp\ipykernel_6744\3033502169.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
 l=df.isnull().sum()
 print(l)
# Out:
# Country name                    0
# Regional indicator              0
# Ladder score                    0
# upperwhisker                    0
# lowerwhisker                    0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Dystopia + residual             0
# dtype: int64

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   Regional indicator            143 non-null    object
#  2   Ladder score                  143 non-null    float64
#  3   upperwhisker                  143 non-null    float64
#  4   lowerwhisker                  143 non-null    float64
#  5   Log GDP per capita            143 non-null    float64
#  6   Social support                143 non-null    float64
#  7   Healthy life expectancy       143 non-null    float64
#  8   Freedom to make life choices  143 non-null    float64
#  9   Generosity                    143 non-null    float64
#  10  Perceptions of corruption     143 non-null    float64
#  11  Dystopia + residual           143 non-null    float64
# dtypes: float64(10), object(2)
# ...

# %%
num_countries = df['Country name'].nunique()
num_regions = df['Regional indicator'].nunique()
print("Number of countries:", num_countries)
print("Number of regions:", num_regions)
max_score=df['Ladder score'].max()
min_score=df['Ladder score'].min()
print("Maximum score:", max_score)
print("Minimum score:", min_score)
# Out:
# Number of countries: 143
# Number of regions: 10
# Maximum score: 7.741
# Minimum score: 1.721

# %%
max_region=df.groupby('Regional indicator')['Ladder score'].max()
print("Maximum score for each region:")
print(max_region)
most_common_region = df['Regional indicator'].value_counts().idxmax()
print("Most common region:", most_common_region)
# Out:
# Maximum score for each region:
# Regional indicator
# Central and Eastern Europe            6.822
# Commonwealth of Independent States    6.195
# East Asia                             6.503
# Latin America and Caribbean           6.955
# Middle East and North Africa          7.341
# North America and ANZ                 7.057
# South Asia                            5.158
# Southeast Asia                        6.523
# Sub-Saharan Africa                    5.816
# Western Europe                        7.741
# Name: Ladder score, dtype: float64
# Most common region: Sub-Saharan Africa

# %% [markdown]
# Part 2 -EDA

# %%
import matplotlib.pyplot as plt
plt.hist(df['Ladder score'], bins=10, edgecolor='black')
plt.xlabel('Ladder score')
plt.ylabel('Frequency')
plt.title('Histogram of Ladder score')
plt.show()

# %%
top_10_happiest = df.sort_values(by='Ladder score', ascending=False).head(10)

print(top_10_happiest[['Country name', 'Ladder score']])
# Out:
#   Country name  Ladder score
# 0      Finland         7.741
# 1      Denmark         7.583
# 2      Iceland         7.525
# 3       Sweden         7.344
# 4       Israel         7.341
# 5  Netherlands         7.319
# 6       Norway         7.302
# 7   Luxembourg         7.122
# 8  Switzerland         7.060
# 9    Australia         7.057

# %%
bottom_10_happiest = df.sort_values(by='Ladder score', ascending=True).head(10)

print(bottom_10_happiest[['Country name', 'Ladder score']])
# Out:
#          Country name  Ladder score
# 142       Afghanistan         1.721
# 141           Lebanon         2.707
# 140           Lesotho         3.186
# 139      Sierra Leone         3.245
# 138  Congo (Kinshasa)         3.295
# 137          Zimbabwe         3.341
# 136          Botswana         3.383
# 135            Malawi         3.421
# 134          Eswatini         3.502
# 133            Zambia         3.502

# %%
average_score_by_region = df.groupby('Regional indicator')['Ladder score'].mean()

print(average_score_by_region)
# Out:
# Regional indicator
# Central and Eastern Europe            6.170941
# Commonwealth of Independent States    5.538500
# East Asia                             5.934333
# Latin America and Caribbean           6.143368
# Middle East and North Africa          5.199941
# North America and ANZ                 6.927750
# South Asia                            3.895667
# Southeast Asia                        5.551889
# Sub-Saharan Africa                    4.329686
# Western Europe                        6.841650
# Name: Ladder score, dtype: float64

# %%
plt.bar(average_score_by_region.index, average_score_by_region.values)
plt.xlabel('Regional indicator')
plt.ylabel('Average score')
plt.title('Average score by regional indicator')
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(df['Log GDP per capita'], df['Ladder score'],
            color='blue', label='Happiness Score', alpha=0.7)

plt.xlabel('Logged GDP per capita')
plt.ylabel('Happiness score')
plt.title('Relationship between Logged GDP per capita and Happiness score')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='Regional indicator', y='Ladder score', data=df)
plt.xlabel('Regional indicator')
plt.ylabel('Happiness score')
plt.xticks(rotation=90)
plt.title('Boxplot of Happiness score by regional indicator')
plt.show()

# %% [markdown]
# part 3-Statistics

# %%
mean_hp=df['Ladder score'].mean()
print("Mean:",mean_hp)
median=df['Ladder score'].median()
print("Median:",median)
var=df['Ladder score'].var()
print("Variance:",var)
std=df['Ladder score'].std()
print("ST deviation:",std)

min=df['Ladder score'].min()
print("Min score:",min)
max=df['Ladder score'].max()
print("Max score:",max)
mode=df['Ladder score'].mode()
print("Mode:",mode)
# Out:
# Mean: 5.52758041958042
# Median: 5.785
# Variance: 1.3705771466561611
# ST deviation: 1.1707165099442995
# Min score: 1.721
# Max score: 7.741
# Mode: 0    3.502
# 1    5.816
# 2    6.188
# Name: Ladder score, dtype: float64

# %%
global_avg = df['Ladder score'].mean()

below_avg_count = df[df['Ladder score'] < global_avg]['Country name'].nunique()


total_countries = df['Country name'].nunique()


percentage_below_avg = (below_avg_count / total_countries) * 100

print(f"Global average happiness score: {global_avg:.2f}")
print("Total countries:",total_countries)
print(f"Number of countries below average: {below_avg_count}")
print(f"Percentage of countries below average: {percentage_below_avg:.2f}%")
# Out:
# Global average happiness score: 5.53
# Total countries: 143
# Number of countries below average: 63
# Percentage of countries below average: 44.06%

# %%
top_20 = df.sort_values(by='Ladder score', ascending=False).head(20)
most_cmn_reg=df['Regional indicator'].value_counts().idxmax()
print("Most common region:",most_cmn_reg)
# Out:
# Most common region: Sub-Saharan Africa

# %% [markdown]
# part 4-linear algebra

# %%
ladder_score=df['Ladder score'].to_numpy()
gdp=df['Log GDP per capita'].to_numpy()
print("Vector addition:",ladder_score+gdp)
print("Vector subtraction:",ladder_score-gdp)
dot_product=np.dot(ladder_score,gdp)
print("Dot product:",dot_product)
# Out:
# Vector addition: [9.585      9.491      9.406      9.222      9.144      9.22
#  9.254      9.263      9.03       8.911      8.839      8.516
#  8.796      8.79       8.74       8.762      8.967      8.605
#  8.584      8.571      8.529      8.716      8.664      8.59
#  8.199      8.207      8.427      8.436      7.925      8.641
#  8.345      8.19       7.734      8.2        8.18       8.187
#  7.949      7.976      8.06       8.173      8.124      7.547
#  7.381      7.702      7.963      7.934      7.407      7.75
#  7.81       7.862      7.846      7.873      7.28       7.374
#  7.758      7.739      7.375      7.46       7.621      7.47
#  7.059      7.33780714 7.652      7.618      7.342      7.392
#  7.122      7.212      7.34       7.386      7.201      7.427
#  7.001      7.04       6.768      7.278      7.049      7.132
#  5.607      6.929      7.092      6.899      6.811      6.844
#  6.688      7.225      6.742      6.65980714 6.113      5.776
# ...

# %%
matrix = df[['Log GDP per capita', 'Social support']].to_numpy()
weight=np.array([0.5,0.5])
print("Weighted matrix multiplication:",np.dot(matrix,weight))
# Out:
# Weighted matrix multiplication: [1.708      1.714      1.749      1.6895     1.658      1.6815
#  1.7345     1.748      1.6975     1.6575     1.6685     1.467
#  1.6045     1.6105     1.6495     1.654      1.7595     1.647
#  1.61       1.574      1.644      1.5735     1.6655     1.6305
#  1.381      1.5135     1.583      1.6015     1.3205     1.7395
#  1.594      1.4675     1.1725     1.6395     1.5775     1.6185
#  1.4645     1.4925     1.547      1.6355     1.564      1.2145
#  1.18       1.3495     1.623      1.604      1.303      1.4715
#  1.5395     1.5055     1.57       1.4965     1.189      1.299
#  1.548      1.625      1.403      1.4155     1.3945     1.368
#  1.063      1.25656786 1.5775     1.48       1.3915     1.313
#  1.302      1.2755     1.3945     1.464      1.331      1.4965
#  1.198      1.233      1.2655     1.4445     1.432      1.339
#  0.6605     1.2725     1.549      1.299      1.379      1.376
#  1.2575     1.5465     1.181      1.25656786 0.757      0.7215
# ...

# %%
ladder_score=df['Ladder score'].to_numpy()
ladder_score_normalized = (ladder_score - ladder_score.min()) / \
                          (ladder_score.max() - ladder_score.min())

print("First 5 normalized values:", ladder_score_normalized)
# Out:
# First 5 normalized values: [1.         0.97375415 0.9641196  0.93405316 0.93355482 0.92990033
#  0.92707641 0.89717608 0.88687708 0.88637874 0.88172757 0.86943522
#  0.86877076 0.86112957 0.860299   0.85930233 0.85       0.84734219
#  0.84667774 0.83521595 0.83421927 0.83255814 0.83122924 0.83023256
#  0.82342193 0.81229236 0.81196013 0.80946844 0.80398671 0.79767442
#  0.79435216 0.7923588  0.78870432 0.78521595 0.78421927 0.7807309
#  0.77906977 0.77059801 0.77026578 0.76827243 0.76461794 0.75847176
#  0.75797342 0.75598007 0.75348837 0.74966777 0.74318937 0.74202658
#  0.74202658 0.72209302 0.72076412 0.72043189 0.71877076 0.7179402
#  0.71578073 0.71362126 0.70697674 0.70681063 0.70664452 0.70631229
#  0.70548173 0.70398671 0.70116279 0.69983389 0.69036545 0.68853821
#  0.6845515  0.68438538 0.68139535 0.68023256 0.68023256 0.67508306
#  0.67491694 0.66511628 0.66328904 0.66212625 0.660299   0.66013289
#  0.64551495 0.63903654 0.62159468 0.62026578 0.61478405 0.60598007
# ...

# %% [markdown]
# Part 5 Calculus

# %%
import sympy as sp
GDP,ladder_score=sp.symbols('GDP ladder_score')
Wellbeing_Index = (GDP*ladder_score) + 0.5*(ladder_score-5)**2
derivative=sp.diff(Wellbeing_Index,ladder_score)
print("Derivative:",derivative)
# Out:
# Derivative: GDP + 1.0*ladder_score - 5.0

# %% [markdown]
# Part 6-Feature engineering

# %%
df['is_happy'] = (df['Ladder score'] > 7).astype(int)
df.head(10)
df['happiness_rank']=df['Ladder score'].rank(ascending=False)
df.head(10)
# Out:
#   Country name            Regional indicator  Ladder score  upperwhisker  \
# 0      Finland                Western Europe         7.741         7.815
# 1      Denmark                Western Europe         7.583         7.665
# 2      Iceland                Western Europe         7.525         7.618
# 3       Sweden                Western Europe         7.344         7.422
# 4       Israel  Middle East and North Africa         7.341         7.405
# 5  Netherlands                Western Europe         7.319         7.383
# 6       Norway                Western Europe         7.302         7.389
# 7   Luxembourg                Western Europe         7.122         7.213
# 8  Switzerland                Western Europe         7.060         7.147
# 9    Australia         North America and ANZ         7.057         7.141
#
#    lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# 0         7.667               1.844           1.572                    0.695
# ...

# %%
mean_gdp=df['Log GDP per capita'].mean()
print("Mean GDP:",mean_gdp)
df['above_avg_gdp']=(df['Log GDP per capita']>mean_gdp).astype(int)
df
# Out:
# Mean GDP: 1.3788071428571427
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %%
df['Life_Expectancy_Quartile'] = pd.qcut(df['Healthy life expectancy'],q=4,labels=['Q1 (Lowest)', 'Q2', 'Q3', 'Q4 (Highest)'])
df
# Out:
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %% [markdown]
# Part 7-SQL simulation in pandas

# %%
countries_with_more_hp_score=df[df['Ladder score']>7]
countries_with_more_hp_score
# Out:
#    Country name            Regional indicator  Ladder score  upperwhisker  \
# 0       Finland                Western Europe         7.741         7.815
# 1       Denmark                Western Europe         7.583         7.665
# 2       Iceland                Western Europe         7.525         7.618
# 3        Sweden                Western Europe         7.344         7.422
# 4        Israel  Middle East and North Africa         7.341         7.405
# 5   Netherlands                Western Europe         7.319         7.383
# 6        Norway                Western Europe         7.302         7.389
# 7    Luxembourg                Western Europe         7.122         7.213
# 8   Switzerland                Western Europe         7.060         7.147
# 9     Australia         North America and ANZ         7.057         7.141
# 10  New Zealand         North America and ANZ         7.029         7.105
#
#     lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# ...

# %%
countries_gdp=df.sort_values(by='Log GDP per capita',ascending=False)
print(countries_gdp[['Country name','Log GDP per capita']].head(10))
# Out:
#                  Country name  Log GDP per capita
# 7                  Luxembourg               2.141
# 16                    Ireland               2.129
# 29                  Singapore               2.118
# 21       United Arab Emirates               1.983
# 8                 Switzerland               1.970
# 6                      Norway               1.952
# 22              United States               1.939
# 85  Hong Kong S.A.R. of China               1.909
# 1                     Denmark               1.908
# 5                 Netherlands               1.901

# %%
region_avg_hp=df.groupby('Regional indicator')['Ladder score'].mean()
print(region_avg_hp)
# Out:
# Regional indicator
# Central and Eastern Europe            6.170941
# Commonwealth of Independent States    5.538500
# East Asia                             5.934333
# Latin America and Caribbean           6.143368
# Middle East and North Africa          5.199941
# North America and ANZ                 6.927750
# South Asia                            3.895667
# Southeast Asia                        5.551889
# Sub-Saharan Africa                    4.329686
# Western Europe                        6.841650
# Name: Ladder score, dtype: float64

# %%
top5regions_avg_hp = df.groupby('Regional indicator')['Ladder score'].mean().sort_values(ascending=False).head(5)
print("Top 5 regions by average happiness score:")
print(top5regions_avg_hp)
# Out:
# Top 5 regions by average happiness score:
# Regional indicator
# North America and ANZ          6.927750
# Western Europe                 6.841650
# Central and Eastern Europe     6.170941
# Latin America and Caribbean    6.143368
# East Asia                      5.934333
# Name: Ladder score, dtype: float64

# %%
countries_high_health_life = df[df['Healthy life expectancy'] > .70]
print(countries_high_health_life[['Country name', 'Regional indicator', 'Healthy life expectancy']])
# Out:
#                  Country name            Regional indicator  \
# 2                     Iceland                Western Europe
# 3                      Sweden                Western Europe
# 4                      Israel  Middle East and North Africa
# 5                 Netherlands                Western Europe
# 6                      Norway                Western Europe
# 7                  Luxembourg                Western Europe
# 8                 Switzerland                Western Europe
# 14                     Canada         North America and ANZ
# 23                    Germany                Western Europe
# 26                     France                Western Europe
# 29                  Singapore                Southeast Asia
# 35                      Spain                Western Europe
# 39                      Malta                Western Europe
# 40                      Italy                Western Europe
# 49                     Cyprus                Western Europe
# ...

# %% [markdown]
# Insights

# %%
happiest_country=df.groupby('Country name')['Ladder score'].max().idxmax()
print("The happiest country is:",happiest_country)
# Out:
# The happiest country is: Finland

# %%
region_avg_happiness = df.groupby('Regional indicator')['Ladder score'].mean()
happiest_region = region_avg_happiness.idxmax()
highest_avg_score = region_avg_happiness.max()

print(f"Happiest region on average: {happiest_region} ({highest_avg_score:.2f})")
# Out:
# Happiest region on average: North America and ANZ (6.93)

# %%
correlation=df['Ladder score'].corr(df['Log GDP per capita'])
print("Correlation:",correlation)
if(correlation>=1):
  print("Strongly correlated")
elif(correlation>0):
  print("Positively correlated")
else:
  print("Negatively correlated")
# Out:
# Correlation: 0.7671814730709576
# Positively correlated

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation = df['Log GDP per capita'].corr(df['Ladder score'])
print(f"Correlation between GDP per capita and happiness: {correlation:.2f}")


plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Log GDP per capita', y='Ladder score')
plt.title('GDP per Capita vs Happiness Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness (Ladder Score)')
plt.show()
# Out:
# Correlation between GDP per capita and happiness: 0.77

# %%
region_avg_life = df.groupby('Regional indicator')['Healthy life expectancy'].mean()

highest_region = region_avg_life.idxmax()
highest_value = region_avg_life.max()

print(f"Region with highest average life expectancy: {highest_region} ({highest_value:.2f} years)")
# Out:
# Region with highest average life expectancy: Western Europe (0.71 years)

# %%
import pandas as pd
import matplotlib.pyplot as plt


region_avg_ladder = df.groupby('Regional indicator')['Ladder score'].mean()


region_avg_gdp = df.groupby('Regional indicator')['Healthy life expectancy'].mean()

fig, axes = plt.subplots(1, 2, figsize=(14, 6))


axes[0].pie(region_avg_ladder, labels=region_avg_ladder.index, autopct='%1.1f%%', startangle=90)
axes[0].set_title("Avg Ladder Score by Region")


axes[1].pie(region_avg_gdp, labels=region_avg_gdp.index, autopct='%1.1f%%', startangle=90)
axes[1].set_title("Health life expectancy")

plt.tight_layout()
plt.show()
